# %%
import pandas as pd

# %%
df=pd.read_csv('lots_of_monsters.csv')
df.head()
# Out:
#                 Name    Size        Type        Tag Alignment   CR    Source  \
# 0          Aarakocra  Medium    Humanoid  Aarakocra        NG  1/4     MM 12
# 1       Aaztar-ghola  Medium    Humanoid        NaN        CE    4     FEF 5
# 2            Abjurer  Medium    Humanoid   Any Race       Any    9  VGtM 209
# 3            Aboleth   Large  Aberration        NaN        LE   10     MM 13
# 4  Aboleth, Nihileth   Large      Undead        NaN        CE   12     ToB 8
#
#   Arctic Coastal Desert  ... Grassland Hill Mountain Swamp Underdark  \
# 0    NaN     NaN    NaN  ...       NaN  NaN        x   NaN       NaN
# 1      x       x      x  ...         x    x        x     x         x
# 2    NaN     NaN    NaN  ...       NaN  NaN      NaN   NaN       NaN
# 3    NaN     NaN    NaN  ...       NaN  NaN      NaN   NaN         x
# 4    NaN     NaN    NaN  ...       NaN  NaN      NaN   NaN         ø
#
#   Underwater Urban Other Plane Unnamed: 19  \
# ...

# %%
df[~df['Arctic'].isna()]
# Out:
#                                Name        Size         Type  \
# 1                      Aaztar-ghola      Medium     Humanoid
# 6                   Abominable Yeti        Huge  Monstrosity
# 27                  Adult Rime Worm       Large    Elemental
# 31               Adult White Dragon        Huge       Dragon
# 38           Air Elemental Myrmodon      Medium    Elemental
# 56    Amphoron of yothri juggernaut       Large    Construct
# 57       Amphoron of yothri warrior      Medium    Construct
# 58        Amphoron of yothri worker       Small    Construct
# 74             Ancient White Dragon  Gargantuan       Dragon
# 80                   Animated Armor      Medium    Construct
# 97                        Archdruid      Medium     Humanoid
# 104             Artificer of yothri      Medium   Aberration
# 113                     Astral moth       Large  Monstrosity
# 131      Baba Yaga’s Horsemen, Base      Medium          Fey
# ...
